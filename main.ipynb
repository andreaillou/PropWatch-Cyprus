# %% [markdown]
# <a href="https://colab.research.google.com/github/andreaillou/PropWatch-Cyprus/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PropWatch Cyprus — End-to-End Pipeline
#
# **Scrape → Merge → Filter → Clean → Lemmatize → Analyse**
#
# Corpus sources:
#
# - **Tier 1**: RT / Sputnik via direct sitemap (`src/scraping/news.py`)
# - **Tier 2/3**: Telegram channels via Telethon (`src/scraping/telegram.py`)
# - **Twitter/X**: Jan 2026 kompromat event (`src/scraping/twitter.py`)
#
# Run cells top-to-bottom. Scraping cells are commented out by default — uncomment to collect fresh data.

# %%
# %pip install trafilatura stanza lingua-language-detector telethon
# Out:
# Collecting trafilatura
#   Downloading trafilatura-2.0.0-py3-none-any.whl.metadata (12 kB)
# Collecting stanza
#   Downloading stanza-1.11.1-py3-none-any.whl.metadata (14 kB)
# Collecting lingua-language-detector
#   Downloading lingua_language_detector-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting telethon
#   Downloading telethon-1.42.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from trafilatura) (2026.2.25)
# Requirement already satisfied: charset_normalizer>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from trafilatura) (3.4.6)
# Collecting courlan>=1.3.2 (from trafilatura)
#   Downloading courlan-1.3.2-py3-none-any.whl.metadata (17 kB)
# Collecting htmldate>=1.9.2 (from trafilatura)
#   Downloading htmldate-1.9.4-py3-none-any.whl.metadata (10 kB)
# Collecting justext>=3.0.1 (from trafilatura)
#   Downloading justext-3.0.2-py2.py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from trafilatura) (6.0.2)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from trafilatura) (2.5.0)
# Collecting emoji (from stanza)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from stanza) (4.9.4)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.12/dist-packages (from stanza) (5.29.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from stanza) (2.32.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from stanza) (3.6.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from stanza) (2.10.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stanza) (4.67.3)
# Collecting udtools>=0.2.4 (from stanza)
#   Downloading udtools-0.2.7-py3-none-any.whl.metadata (13 kB)
# Collecting pyaes (from telethon)
#   Downloading pyaes-1.6.1.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: rsa in /usr/local/lib/python3.12/dist-packages (from telethon) (4.9.1)
# Requirement already satisfied: babel>=2.16.0 in /usr/local/lib/python3.12/dist-packages (from courlan>=1.3.2->trafilatura) (2.18.0)
# Collecting tld>=0.13 (from courlan>=1.3.2->trafilatura)
#   Downloading tld-0.13.2-py2.py3-none-any.whl.metadata (11 kB)
# Collecting dateparser>=1.1.2 (from htmldate>=1.9.2->trafilatura)
#   Downloading dateparser-1.3.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: python-dateutil>=2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from htmldate>=1.9.2->trafilatura) (2.9.0.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.13.0->stanza) (1.4.3)
# Collecting udapi>=0.5.0 (from udtools>=0.2.4->stanza)
#   Downloading udapi-0.5.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: regex>=2020.09.27 in /usr/local/lib/python3.12/dist-packages (from udtools>=0.2.4->stanza) (2025.11.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (3.11)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from rsa->telethon) (0.6.3)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.12/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura) (2025.2)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura) (5.3.1)
# Collecting lxml_html_clean (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura)
#   Downloading lxml_html_clean-0.4.4-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.9.0.post0->htmldate>=1.9.2->trafilatura) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->stanza) (1.3.0)
# Collecting colorama (from udapi>=0.5.0->udtools>=0.2.4->stanza)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from udapi>=0.5.0->udtools>=0.2.4->stanza) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->stanza) (3.0.3)
# Downloading trafilatura-2.0.0-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 9.5 MB/s eta 0:00:00
# Downloading stanza-1.11.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 54.9 MB/s eta 0:00:00
# Downloading lingua_language_detector-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (170.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 MB 6.6 MB/s eta 0:00:00
# Downloading telethon-1.42.0-py3-none-any.whl (748 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 748.5/748.5 kB 59.9 MB/s eta 0:00:00
# Downloading courlan-1.3.2-py3-none-any.whl (33 kB)
# Downloading htmldate-1.9.4-py3-none-any.whl (31 kB)
# Downloading justext-3.0.2-py2.py3-none-any.whl (837 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.9/837.9 kB 65.3 MB/s eta 0:00:00
# Downloading udtools-0.2.7-py3-none-any.whl (773 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.7/773.7 kB 61.3 MB/s eta 0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 48.8 MB/s eta 0:00:00
# Downloading dateparser-1.3.0-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 35.5 MB/s eta 0:00:00
# Downloading tld-0.13.2-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 33.5 MB/s eta 0:00:00
# Downloading udapi-0.5.2-py3-none-any.whl (418 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.7/418.7 kB 44.7 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading lxml_html_clean-0.4.4-py3-none-any.whl (14 kB)
# Building wheels for collected packages: pyaes
#   Building wheel for pyaes (setup.py) ... done
#   Created wheel for pyaes: filename=pyaes-1.6.1-py3-none-any.whl size=26347 sha256=293e955383f469bfcd0c28b112822d1800f6080fac68525c98624a77ad96af3e
#   Stored in directory: /root/.cache/pip/wheels/d9/43/32/ec313dd557e88e419489b9df40c04dad7b99576bde162496f8
# Successfully built pyaes
# Installing collected packages: pyaes, tld, lxml_html_clean, lingua-language-detector, emoji, colorama, udapi, telethon, dateparser, courlan, udtools, justext, htmldate, trafilatura, stanza
# Successfully installed colorama-0.4.6 courlan-1.3.2 dateparser-1.3.0 emoji-2.15.0 htmldate-1.9.4 justext-3.0.2 lingua-language-detector-2.2.0 lxml_html_clean-0.4.4 pyaes-1.6.1 stanza-1.11.1 telethon-1.42.0 tld-0.13.2 trafilatura-2.0.0 udapi-0.5.2 udtools-0.2.7

# %%
import os, sys
from google.colab import drive
# 1. Mount your persistent Google Drive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import getpass

# 1. This will generate a URL in your IDE's output console
auth.authenticate_user()

# 2. Click the URL, log in via your browser, and it will give you an authorization code.
# Paste that code back into the input box that appears in your IDE.

# 3. Mount the drive silently in the background
# !mkdir -p /content/drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)


# 2. Securely read the GitHub token from the Drive .env file
env_file_path = '/content/drive/MyDrive/PropWatch_Data/.env'

with open(env_file_path, 'r') as file:
    for line in file:
        # Replace 'GITHUB_PAT=' with whatever you named your token in the .env file
        if line.startswith('GITHUB_PAT='):
            # This extracts the token and saves it as a background environment variable
            # The .strip() ensures we remove any accidental quotes or spaces
            os.environ['GITHUB_PAT'] = line.strip().split('=', 1)[1].strip('"\'')
            break

# 3. Sync Code: Clone using the hidden environment variable ($GITHUB_PAT)
# %cd /content
if not os.path.exists('/content/PropWatch-Cyprus'):
    # Using $GITHUB_PAT injects the token securely without it being visible in the cell code!
    # !git clone https://$GITHUB_PAT@github.com/andreaillou/PropWatch-Cyprus.git
else:
    # %cd /content/PropWatch-Cyprus
    # If the repo is already there, we just pull the latest changes
    # !git pull

# 4. Copy the .env file into the repo so your Python code can load it normally
# !cp {env_file_path} /content/PropWatch-Cyprus/.env

# 5. The Magic Trick: Create a Symlink for the Data
# !rm -rf /content/PropWatch-Cyprus/data
# !ln -s /content/drive/MyDrive/PropWatch_Data /content/PropWatch-Cyprus/data

# 6. Point Python to the codebase
sys.path.append('/content/PropWatch-Cyprus')
os.chdir('/content/PropWatch-Cyprus')

print("✅ Environment securely synced and ready!")
# Out:
# Mounted at /content/drive
# /content
# Cloning into 'PropWatch-Cyprus'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 50 (delta 10), reused 44 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 51.25 KiB | 7.32 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# ✅ Environment securely synced and ready!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
from dotenv import load_dotenv
load_dotenv(override=True)  # must run before any src.* imports

import pandas as pd
import os
import torch # Import torch here

# Define env_file_path here for robustness, as it's used later in this cell
env_file_path = '/content/drive/MyDrive/PropWatch_Data/.env'
# Ensure the target directory for the 'data' symlink exists on Google Drive.
# This prevents errors when src.config tries to create subdirectories.
os.makedirs('/content/drive/MyDrive/PropWatch_Data', exist_ok=True)

from src.config import (
    RAW_CSV, PRECLEANED_CSV, CLEAN_CSV,
    CYRILLIC_CSV, LATIN_CSV, GREEK_CSV,
    CYRILLIC_LEMMATIZED_CSV, GREEK_LEMMATIZED_CSV, LATIN_LEMMATIZED_CSV,
    WORD_FREQ_CSV, BIGRAMS_CSV, TRIGRAMS_CSV,
    LATIN_WORD_FREQ_CSV, LATIN_BIGRAMS_CSV, LATIN_TRIGRAMS_CSV,
    GREEK_WORD_FREQ_CSV, GREEK_BIGRAMS_CSV, GREEK_TRIGRAMS_CSV,
    ARCHIVED_RAW_DIR, TWITTER_RAW_CSV,
)
from src.scraping.telegram import scrape_channels
from src.scraping.news import scrape_all_tier1
#from src.scraping.twitter import scrape_twitter
from src.preprocessing.filtering import filter_messages, tag_categories
from src.preprocessing.text_cleaning import clean_and_split
from src.analysis.lemmatization import lemmatize_column, lemmatize_greek_column, lemmatize_english_column
from src.analysis.frequency import ensure_list_column, word_frequency, compute_ngrams

from huggingface_hub import login
hf_token = os.getenv('HF_TOKEN')
if hf_token:
    login(token=hf_token, add_to_git_credential=False)
    print('✅ HuggingFace authenticated')
else:
    print('⚠️ HF_TOKEN not found in .env')

with open(env_file_path, 'r') as file:
    for line in file:
        if line.startswith('HF_TOKEN='):
            os.environ['HF_TOKEN'] = line.strip().split('=', 1)[1].strip('"\'')
            break

print('Imports OK')
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# ✅ HuggingFace authenticated
# Imports OK

# %% [markdown]
# ## 1. Scrape — Tier 1 (RT / Sputnik via sitemap)

# %%
# Requires sitemap_index entries in configs/channels.yaml.
# RT English and RT Russian are pre-configured.
# Output saved per-domain to data/raw/archived/ + merged tier1_archived_raw.csv

#df_tier1 = scrape_all_tier1()

# Load existing:
tier1_path = ARCHIVED_RAW_DIR / 'tier1_archived_raw.csv'
df_tier1 = pd.read_csv(tier1_path) if tier1_path.exists() else pd.DataFrame()
print(f'Tier 1 articles loaded: {len(df_tier1)}')
# Out:
# Tier 1 articles loaded: 500

# %% [markdown]
# ## 2. Scrape — Tier 2 / 3 (Telegram channels)

# %%
# Requires TELEGRAM_APP_ID and TELEGRAM_API_HASH in .env
# Channels loaded from configs/channels.yaml (archived: false entries only)
# First run will prompt for phone number + Telegram auth code in terminal.

# df_telegram = await scrape_channels()

# Load existing:
from src.config import RAW_CSV
df_telegram = pd.read_csv(RAW_CSV) if RAW_CSV.exists() else pd.DataFrame()
print(f'Telegram messages loaded: {len(df_telegram)}')
# Out:
# Telegram messages loaded: 9179

# %% [markdown]
# ## 3. Scrape — Twitter/X (Jan 2026 kompromat event)

# %%
# Requires TWITTER_BEARER_TOKEN in .env
# Targets the coordinated operation against President Christodoulides (Jan 2026)
# Note: Twitter API v2 free tier covers last 7 days only.
# For full Jan 2026 window, a Pro/Academic tier token is required.

# df_twitter = scrape_twitter()

# Load existing:
df_twitter = pd.read_csv(TWITTER_RAW_CSV) if TWITTER_RAW_CSV.exists() else pd.DataFrame()
print(f'Tweets loaded: {len(df_twitter)}')
# Out:
# Tweets loaded: 0

# %% [markdown]
# ## 4. Merge corpus

# %%
# Combine all sources into one DataFrame.
# source_url column is present in Tier 1 and Twitter but not Telegram — fillna handles it.
frames = [df for df in [df_tier1, df_telegram] if not df.empty]
# frames = [df for df in [df_tier1, df_telegram, df_twitter] if not df.empty]

if not frames:
    raise RuntimeError('No data loaded — run at least one scraper first.')

df_raw = pd.concat(frames, ignore_index=True)
df_raw['source_url'] = df_raw.get('source_url', pd.Series(dtype=str)).fillna('')

df_raw.to_csv(RAW_CSV, index=False)
print(f'Merged corpus: {len(df_raw)} rows ({len(df_tier1)} Tier1 | {len(df_telegram)} Telegram)')
# print(f'Merged corpus: {len(df_raw)} rows ({len(df_tier1)} Tier1 | {len(df_telegram)} Telegram | {len(df_twitter)} Twitter)')

df_raw.head()
# Out:
# Merged corpus: 9679 rows (500 Tier1 | 9179 Telegram)
#                          message_id                       date  \
# 0  d58a817b4b069a9362cf6e921eaab12f  2024-10-08T11:07:44+03:00
# 1  17fbe04ca2bf29d60ef02dd8366ae113  2024-10-08T11:08:21+03:00
# 2  be6a86ef8ec0c0379ed412685d37d16d  2024-10-08T11:08:34+03:00
# 3  225cd19ad2ea9c42dec88c69857561b6  2024-10-08T11:08:45+03:00
# 4  cf1a0845c406c3c3275c8e36597f1ee6  2024-10-08T11:09:11+03:00
#
#             channel          region  \
# 0  verginatv.com.cy  tier1_archived
# 1  verginatv.com.cy  tier1_archived
# 2  verginatv.com.cy  tier1_archived
# 3  verginatv.com.cy  tier1_archived
# 4  verginatv.com.cy  tier1_archived
#
#                                                 text  views  forwards  \
# 0  [ad_1]\nΗ Χεζμπολάχ του Λιβάνου ανακοίνωσε αργ...      0         0
# 1  [ad_1]\nΤο ιρανικό κοινοβούλιο φαίνεται αποφασ...      0         0
# 2  [ad_1]\nΣήμερα, Δευτέρα 7 Οκτωβρίου πραγματοπο...      0         0
# 3  [ad_1]\n«Ο Θεός να σώζει τον Τσάρο!», ήταν ένα...      0         0
# 4  [ad_1]\nΜε αφορμή τη συμπλήρωση ενός έτους αύρ...      0         0
#
#    reactions  reply_to_id edit_date  \
# 0          0          NaN       NaN
# 1          0          NaN       NaN
# 2          0          NaN       NaN
# 3          0          NaN       NaN
# 4          0          NaN       NaN
#
#                                           source_url
# 0  https://verginatv.com.cy/2024/10/08/%cf%81%ce%...
# 1  https://verginatv.com.cy/2024/10/08/%cf%84%ce%...
# 2  https://verginatv.com.cy/2024/10/08/%ce%b9%cf%...
# 3  https://verginatv.com.cy/2024/10/08/%ce%bf-%ce...
# 4  https://verginatv.com.cy/2024/10/08/%cf%80%cf%...

# %% [markdown]
# ## 5. Filter & tag

# %%
import torch
print(torch.cuda.is_available())          # should print: True
print(torch.cuda.get_device_name(0))      # should print: Tesla T4
# Out:
# True
# Tesla T4

# %%
df_filtered = filter_messages(df_raw)
df_tagged = tag_categories(df_filtered)
df_tagged.to_csv(PRECLEANED_CSV, index=False)
print(f'Saved {len(df_tagged)} pre-cleaned rows to {PRECLEANED_CSV}')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/558M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# DebertaV2ForSequenceClassification LOAD REPORT from: MoritzLaurer/mDeBERTa-v3-base-mnli-xnli
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# deberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spm.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# NLI scoring:   0%|          | 0/281 [00:00<?, ?it/s]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Saved 638 pre-cleaned rows to /content/PropWatch-Cyprus/data/processed/corpus_precleaned.csv

# %% [markdown]
# ## 6. Clean text & split by language

# %%
df_clean = pd.read_csv(PRECLEANED_CSV)
df_all, df_ru, df_en, df_gr = clean_and_split(df_clean)

df_all.to_csv(CLEAN_CSV, index=False)
df_ru.to_csv(CYRILLIC_CSV, index=False)
df_en.to_csv(LATIN_CSV, index=False)
df_gr.to_csv(GREEK_CSV, index=False)
print(f'Saved clean data ({len(df_all)} total | {len(df_ru)} Russian | {len(df_en)} English | {len(df_gr)} Greek)')
# Out:
# Saved clean data (638 total | 401 Russian | 173 English | 62 Greek)

# %% [markdown]
# ## 7. Lemmatize

# %%
# Russian — stanza ru pipeline
df_cyr = pd.read_csv(CYRILLIC_CSV)
print(f'Loaded Russian data for lemmatization: {len(df_cyr)} rows from {CYRILLIC_CSV}')
df_cyr = lemmatize_column(df_cyr)
df_cyr.to_csv(CYRILLIC_LEMMATIZED_CSV, index=False)
print(f'Russian lemmatized: {len(df_cyr)} rows → {CYRILLIC_LEMMATIZED_CSV}')

# Greek — stanza el pipeline
df_gr = pd.read_csv(GREEK_CSV)
print(f'Loaded Greek data for lemmatization: {len(df_gr)} rows from {GREEK_CSV}')
df_gr = lemmatize_greek_column(df_gr)
df_gr.to_csv(GREEK_LEMMATIZED_CSV, index=False)
print(f'Greek lemmatized:  {len(df_gr)} rows → {GREEK_LEMMATIZED_CSV}')

# English — spaCy en_core_web_lg (RT/Sputnik articles + English Telegram posts)
if LATIN_CSV.exists():
    # Download the spaCy model if it's not already present
    try:
        import spacy
        spacy.load("en_core_web_lg")
    except OSError:
        print("Downloading spaCy model 'en_core_web_lg'...")
        # !python -m spacy download en_core_web_lg
        import spacy # Re-import spacy after download
    df_en = pd.read_csv(LATIN_CSV)
    print(f'Loaded English data for lemmatization: {len(df_en)} rows from {LATIN_CSV}')
    df_en = lemmatize_english_column(df_en)
    df_en.to_csv(LATIN_LEMMATIZED_CSV, index=False)
    print(f'English lemmatized: {len(df_en)} rows → {LATIN_LEMMATIZED_CSV}')
else:
    print('No English posts found — skipping English lemmatization')
# Out:
# Loaded Russian data for lemmatization: 401 rows from /content/PropWatch-Cyprus/data/processed/russian_posts.csv
# Russian lemmatized: 4321 rows → /content/PropWatch-Cyprus/data/processed/russian_posts_lemmatized.csv
# Loaded Greek data for lemmatization: 62 rows from /content/PropWatch-Cyprus/data/processed/greek_posts.csv
# Greek lemmatized:  136 rows → /content/PropWatch-Cyprus/data/processed/greek_posts_lemmatized.csv
# Loaded English data for lemmatization: 173 rows from /content/PropWatch-Cyprus/data/processed/english_posts.csv
# English lemmatized: 581 rows → /content/PropWatch-Cyprus/data/processed/english_posts_lemmatized.csv

# %% [markdown]
# ## 8. Word frequency & n-gram analysis

# %%
# ── Russian ───────────────────────────────────────────────────────────────────
df_ru = pd.read_csv(CYRILLIC_LEMMATIZED_CSV)
df_ru['lemmas'] = ensure_list_column(df_ru['lemmas'])
wf = word_frequency(df_ru['lemmas'])
wf.to_csv(WORD_FREQ_CSV, index=False)
bg = compute_ngrams(df_ru['lemmas'], n=2, min_freq=3)
tg = compute_ngrams(df_ru['lemmas'], n=3, min_freq=3)
bg.to_csv(BIGRAMS_CSV, index=False)
tg.to_csv(TRIGRAMS_CSV, index=False)
print('Russian — top 20 words:')
print(wf.head(20).to_string(index=False))

# ── English ───────────────────────────────────────────────────────────────────
if LATIN_LEMMATIZED_CSV.exists(): # Check for lemmatized CSV
    df_en = pd.read_csv(LATIN_LEMMATIZED_CSV) # Load lemmatized English data
    # The 'lemmas' column should already exist, but ensure it's a list for processing
    df_en['lemmas'] = ensure_list_column(df_en['lemmas'])
    wf_en = word_frequency(df_en['lemmas'])
    wf_en.to_csv(LATIN_WORD_FREQ_CSV, index=False)
    compute_ngrams(df_en['lemmas'], n=2, min_freq=3).to_csv(LATIN_BIGRAMS_CSV, index=False)
    compute_ngrams(df_en['lemmas'], n=3, min_freq=3).to_csv(LATIN_TRIGRAMS_CSV, index=False)
    print(f'English word freq saved ({len(wf_en)} unique lemmas)')
else:
    print('No English lemmatized posts found — skipping English word frequency and n-gram analysis')

# ── Greek ─────────────────────────────────────────────────────────────────────
if GREEK_LEMMATIZED_CSV.exists():
    df_gr = pd.read_csv(GREEK_LEMMATIZED_CSV)
    df_gr['lemmas'] = ensure_list_column(df_gr['lemmas'])
    wf_gr = word_frequency(df_gr['lemmas'])
    wf_gr.to_csv(GREEK_WORD_FREQ_CSV, index=False)
    compute_ngrams(df_gr['lemmas'], n=2, min_freq=3).to_csv(GREEK_BIGRAMS_CSV, index=False)
    compute_ngrams(df_gr['lemmas'], n=3, min_freq=3).to_csv(GREEK_TRIGRAMS_CSV, index=False)
    print(f'Greek word freq saved ({len(wf_gr)} unique lemmas)')
else:
    print('No Greek lemmatized posts found — skipping Greek word frequency and n-gram analysis')
# Out:
# Russian — top 20 words:
#        word  frequency
#         год       6155
#      россия       5588
#     который       4986
#  российский       4328
#        весь       2891
#      страна       2812
#        свой       2757
#     украина       2640
#        мочь       2612
#       новый       2396
#       также       2265
#         сша       2258
#  украинский       2222
#       стать       2187
#        один       2142
#  поддержать       2065
#       время       1998
#       война       1935
#       такой       1925
# направление       1899
# English word freq saved (100 unique lemmas)
# Greek word freq saved (100 unique lemmas)

# %% [markdown]
# ## 9. Propaganda classification (planned)
#
# Once `src/classification/model.py` is implemented and weights are placed in `models/`,
# uncomment the cell below.

# %%
# from src.classification.model import PropagandaClassifier
# clf = PropagandaClassifier()
# clf.load_model(MODELS_DIR / "xlm-roberta-propaganda")
# df_ru_clean = pd.read_csv(CYRILLIC_CSV)
# predictions = clf.predict(df_ru_clean['text_cleaned'].tolist())

# %% [markdown]
# ## 10. BERTopic clustering (planned)
#
# H1 (technique distribution) and H4 (narrative drift over time).
# Implement in `src/clustering/bertopic_pipeline.py`.

# %%
# from src.clustering.bertopic_pipeline import run_bertopic
# topics, topic_model = run_bertopic(df_ru['text_cleaned'].tolist())

# %% [markdown]
# ## 11. Interrupted time series — Jan 2026 kompromat event (planned)
#
# H3: detectable structural break in technique intensity around Jan 2026.
# Implement in `src/stats/its.py`.

# %%
# from src.stats.its import run_its
# results = run_its(df_raw)
